# %%
import pandas as pd
import numpy as np

# %%
tr = pd.read_csv("train.csv")

# %%
tt = pd.read_csv("test.csv")

# %%
tr.head()
# Out:
#         loan_id source       financial_institution  interest_rate  \
# 0  268055008619      Z  Turner, Baldwin and Rhodes          4.250
# 1  672831657627      Y  Swanson, Newton and Miller          4.875
# 2  742515242108      Z              Thornton-Davis          3.250
# 3  601385667462      X                       OTHER          4.750
# 4  273870029961      X                       OTHER          4.750
#
#    unpaid_principal_bal  loan_term origination_date first_payment_date  \
# 0                214000        360       2012-03-01            05/2012
# 1                144000        360       2012-01-01            03/2012
# 2                366000        180       2012-01-01            03/2012
# 3                135000        360       2012-02-01            04/2012
# 4                124000        360       2012-02-01            04/2012
#
#    loan_to_value  number_of_borrowers  ...  m4  m5 m6  m7  m8  m9  m10  m11  \
# ...

# %%
tr1 = tr.drop('loan_id', axis=1)

# %%
tr1_dummies = pd.get_dummies(tr1)

# %%
tr1_dummies.head()
# Out:
#    interest_rate  unpaid_principal_bal  loan_term  loan_to_value  \
# 0          4.250                214000        360             95
# 1          4.875                144000        360             72
# 2          3.250                366000        180             49
# 3          4.750                135000        360             46
# 4          4.750                124000        360             80
#
#    number_of_borrowers  debt_to_income_ratio  borrower_credit_score  \
# 0                  1.0                  22.0                  694.0
# 1                  1.0                  44.0                  697.0
# 2                  1.0                  33.0                  780.0
# 3                  2.0                  44.0                  633.0
# 4                  1.0                  43.0                  681.0
#
#    insurance_percent  co-borrower_credit_score  insurance_type  ...  \
# 0               30.0                       0.0             0.0  ...
# ...

# %%
tt1 = tt.drop('loan_id', axis=1)

# %%
tt1_dummies = pd.get_dummies(tt1)`

# %%
x1 = tt1_dummies

# %%
x = tr1_dummies.drop('m13', axis=1)

# %%
y = tr1_dummies.m13

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier(criterion='gini', max_depth=None)

# %%
dtree.fit(x, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
predictions = dtree.predict(x1)

# %%
print(predictions)
# Out:
# [0 0 0 ... 0 0 0]

# %%
#prediction = np.arange(1, len(prediction)+1)

# %%
prediction = pd.DataFrame(predictions)

# %%
prediction.to_csv("C:\\Users\\syed ahmad shabaz\\Documents\\analytics vidhya\\Loan-Delinquency-Prediction\\dataset\\pred.csv")
